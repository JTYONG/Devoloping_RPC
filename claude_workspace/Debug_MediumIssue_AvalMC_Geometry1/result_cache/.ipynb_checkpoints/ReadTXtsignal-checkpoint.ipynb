# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the file - whitespace-separated, skip comment lines starting with #
df = pd.read_csv(
    "signal_BottomGraphite.txt",
    sep=r'\s+',
    comment='#',
    header=None,
    names=['TimeBin', 'Time_ns', 'ElectronSignal', 'IonSignal', 'TotalSignal']
)
plt.figure(figsize=(9, 5))
plt.plot(df['Time_ns'], df['ElectronSignal'], marker='o', linestyle='-', color='steelblue')
plt.xlabel('Time [ns]')
plt.ylabel('Electron Signal')
plt.title('RPC Induced Electron Signal at BottomGraphite')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
df4 = pd.read_csv(
    "signal_BottomReadout.txt",
    sep=r'\s+',
    comment='#',
    header=None,
    names=['TimeBin', 'Time_ns', 'ElectronSignal', 'IonSignal', 'TotalSignal']
)
plt.figure(figsize=(9, 5))
plt.plot(df4['Time_ns'], df3['ElectronSignal'], marker='o', linestyle='-', color='steelblue')
plt.xlabel('Time [ns]')
plt.ylabel('Electron Signal')
plt.title('RPC Induced Electron Signal at Top Readout')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
df2 = pd.read_csv(
    "signal_BottomReadout.txt",
    sep=r'\s+',
    comment='#',
    header=None,
    names=['TimeBin', 'Time_ns', 'ElectronSignal', 'IonSignal', 'TotalSignal']
)
plt.figure(figsize=(9, 5))
plt.plot(df2['Time_ns'], df2['ElectronSignal'], marker='o', linestyle='-', color='steelblue')
plt.xlabel('Time [ns]')
plt.ylabel('Electron Signal [fC/ns]')
plt.title('RPC Induced Electron Signal at Bottom Readout')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
df3 = pd.read_csv(
    "signal_TopReadout.txt",
    sep=r'\s+',
    comment='#',
    header=None,
    names=['TimeBin', 'Time_ns', 'ElectronSignal', 'IonSignal', 'TotalSignal']
)
plt.figure(figsize=(9, 5))
plt.plot(df3['Time_ns'], df3['ElectronSignal'], marker='o', linestyle='-', color='steelblue')
plt.xlabel('Time [ns]')
plt.ylabel('Electron Signal[fC/ns]')
plt.title('RPC Induced Electron Signal at Top Readout')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
