# %%
import uproot
import numpy as np
import pandas as pd

file = uproot.open("signal.root")
file.keys()
# Out:
# ['TopReadout;1', 'BottomReadout;1', 'TopGraphite;1', 'BottomGraphite;1']

# %%
BRead = file["BottomReadout;1"]
BRead.keys()
# Out:
# ['Time Bin', 'Electron Signal', 'Ion Signal', 'Total Signal']

# %%
BRead["Time Bin"].values()
# Out:
# []

# %%
BRead["Electron Signal"].values()
# Out:
# []

# %%
BRead["Ion Signal"].values()
# Out:
# []
