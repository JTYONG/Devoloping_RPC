# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
df = pd.read_csv("signal_BottomGraphite.txt", delimiter="\t", skiprows=1).fillna(0.0)

# %%
df
# Out:
#      # TimeBin  Time[ns]  ElectronSignal     IonSignal  TotalSignal
# 0            0     0.008       -0.000165 -3.815627e-07    -0.000165
# 1            1     0.024       -0.000200 -5.084560e-07    -0.000201
# 2            2     0.040       -0.000185 -4.429928e-07    -0.000185
# 3            3     0.056       -0.000175 -4.263651e-07    -0.000176
# 4            4     0.072       -0.000124 -6.641359e-07    -0.000125
# ..         ...       ...             ...           ...          ...
# 495        495     7.928       -0.000968 -9.833327e-05    -0.001067
# 496        496     7.944       -0.001016 -9.862781e-05    -0.001114
# 497        497     7.960       -0.001080 -9.834097e-05    -0.001179
# 498        498     7.976       -0.000868 -9.399826e-05    -0.000962
# 499        499     7.992       -0.000946 -9.275090e-05    -0.001038
#
# [500 rows x 5 columns]

# %%
figure,ax =  plt.subplots(3,1,figsize=(12, 12))
ax[0].plot(df[df.keys()[1]],df[df.keys()[3]],marker='x',label="Ion Signal")
ax[0].plot(df[df.keys()[1]],df[df.keys()[2]],marker='x',label="Electron Signal")

ax[0].legend()
