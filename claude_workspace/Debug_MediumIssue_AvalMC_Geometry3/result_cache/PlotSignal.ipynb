# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
df = pd.read_csv("signal_BottomGraphite.txt", delimiter="\t", skiprows=1).fillna(0.0)

# %%
df
# Out:
#      # TimeBin  Time[ns]  ElectronSignal  IonSignal  TotalSignal
# 0            0     0.008       -0.000317  -0.000001    -0.000318
# 1            1     0.024       -0.000364  -0.000001    -0.000366
# 2            2     0.040       -0.000395  -0.000001    -0.000396
# 3            3     0.056       -0.000357  -0.000001    -0.000359
# 4            4     0.072       -0.000326  -0.000001    -0.000327
# ..         ...       ...             ...        ...          ...
# 495        495     7.928       -0.000009  -0.000008    -0.000017
# 496        496     7.944       -0.000010  -0.000007    -0.000017
# 497        497     7.960       -0.000009  -0.000008    -0.000017
# 498        498     7.976       -0.000009  -0.000008    -0.000018
# 499        499     7.992       -0.000009  -0.000008    -0.000017
#
# [500 rows x 5 columns]

# %%
figure,ax =  plt.subplots(3,1,figsize=(12, 12))
ax[0].plot(df[df.keys()[1]],df[df.keys()[3]],marker='x',label="Ion Signal")
ax[0].plot(df[df.keys()[1]],df[df.keys()[2]],marker='x',label="Electron Signal")

ax[0].legend()
